# %%
# this is just a copy and paste of the vectorize restaurants script

#########################################################################################################################
# Vectorize a restaurant given its Yelp data
########################################################################################################################


import json

business_file_path = "../yelp_dataset/yelp_academic_dataset_business.json"
review_file_path = "../yelp_dataset/yelp_academic_dataset_review.json"

business_info_dict = {}
with open(business_file_path, 'r') as business_data:
	for b in business_data:
		b_dict = json.loads(b)

		bid = b_dict['business_id']
		category = b_dict["categories"]
		if (category is None) :
			continue
		else:
			if ("Restaurants" in category):
				business_info_dict[bid] = b_dict

print(len(business_info_dict))

restaurant_ids = business_info_dict.keys()
# print(restaurant_ids)
review_info_dict = {}
with open(review_file_path, 'r') as review_data:
	for r in review_data:
		r_dict = json.loads(r)

		bid = r_dict['business_id']
		# print(bid)
		if (bid in restaurant_ids): # this is a restaurant
			if (bid in review_info_dict):
				review_info_dict[bid].append(r_dict)
			else:
				review_info_dict[bid] = [r_dict]

print(len(review_info_dict))
# Out:
# 50763
# 50763

# %%
review_info_dict['xRnhBtG63UNqQaC7wJUUZA']
# Out:
# [{'review_id': 'lLk4H2UPPNxNfUqNZSFbBw',
#   'user_id': 'N3Nr1OwKDfTvZo4ouoTpwQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "The only reason I give this restaurant two stars is because of the location. This was the worst meal I've had in a long time. Everything was greasy and COLD, the biscuit was hard, and it was not the cleanest, presentation was horrible. I will not be returning.",
#   'date': '2017-08-07 22:30:35'},
#  {'review_id': '57eMLeLoA3cZCmhJEttnlg',
#   'user_id': 'htj4Av98Kj0YxZpPfvtkBQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This place rocks. Food is great and they are very friendly. Very clean and even though it can get crowded, it is worth the wait.',
#   'date': '2015-08-19 04:39:20'},
#  {'review_id': '6thyjKRUNilf8S7uxno_Tw',
#   'user_id': 'iuDcf6brl6_pFII3szVKeA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Great barbecue. We ordered mac & cheese for the kids, pulled pork, baked beans, coleslaw and the burnt ends.  Everything was fantastic. Best barbecue this side of Kansas City.',
#   'date': '2016-08-12 21:56:08'},
#  {'review_id': 'QDIWb70iLgIqBt7g5l3nLA',
#   'user_id': '3-UpUjvU85T_A2oqh2XL8Q',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Nothing fancy but the food was delicious. The sides are just as yummy and your main meal.',
#   'date': '2016-01-17 11:44:25'},
#  {'review_id': 'Qkab5C7pdAAfH9GGPTNyHA',
#   'user_id': 'dW2SUT2qPzbmHyY51L8qqA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 1,
#   'cool': 1,
#   'text': 'Finally, we decided to check this place out and I will say that it\'s a well oiled machine. They definitely know how to get you in and out. Personally, I\'m not a cafeteria style person, but it works. Now, onto the food. In the world of "traditional" BBQ joints,  I would say that 4 Rivers works better for families, cause they have something for everyone. They even offer a Cuban! While it borders on very good, its definitely not great bbq, not even close.',
#   'date': '2015-06-08 19:23:21'},
#  {'review_id': 'rrIG0d3fx9mcTJMDe0wb9g',
#   'user_id': 'k5Q5pLhBom32MukTcYyLvA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "We really enjoyed our dinner. The portions were pretty large, which for a bbq place is unusual. I had the beef brisket which was very tender and juicy but not fatty (i like the lean brisket over the fatty). My friends had the burnt ends and liked it a lot. I say it easily beats Famous Dave's, Dickey's, Sonny's, and Mission bbq. I will definitely be back.",
#   'date': '2016-06-11 22:32:12'},
#  {'review_id': '6iA-dcmkPk34aXNwFUoJuw',
#   'user_id': 'CLISa_cfsE09NGNRVMwwWA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'We just love 4Rivers. The sides are delicious (the corn and the okra are my personal faves)...and try the Burnt Ends sandwich! Yummm!',
#   'date': '2018-05-28 20:49:11'},
#  {'review_id': 'LPJcQ43N3LI1UAERqkUddg',
#   'user_id': 'zbJ7jeMBmUGGTvIoOHtzcw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Such a FAN!!  Not only is the food SUPER the owner is also.  They do so much for the community.  Everything is always fresh and tasty.  Some of their plates are big enough to share EASY.  This location even has a desert shop.  Sit anywhere and make new friends....it is often a little loud but after one bite you will not care.',
#   'date': '2015-03-18 21:07:26'},
#  {'review_id': 'fOdZNj_NReKgWutBDPkQ8Q',
#   'user_id': 'mSiMObA9JTrHYqMuCl_ScQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Ordered the longhorn stacker with fries and cornbread. Only thing that was good were the fries and cornbread. The stacker was so dry and flavorless I'm so disappointed because this was my first time trying the restaurant. Add some sauce or something to the sandwich before we choke on it.",
#   'date': '2017-12-02 23:12:50'},
#  {'review_id': 'IgeOy287lLBwEnAt-VGJRQ',
#   'user_id': 'ijWc7boCzkbxmuthI3q4Sw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 2,
#   'funny': 2,
#   'cool': 2,
#   'text': "Delicious, quick food! \n\nI'm not the biggest fan of American barbecue but I sure do love 4 Rivers! They have a good amount of choices for meats and so many sides!! I always order the tri tip for myself. It's covered and cilantro which is a plus for me but if you don't like cilantro then this may not be for you. I've tried their other meats from some of my friends such as their brisket and pulled pork which are both delicious options. As far as their sides go, there are so many options to choose from! Some of you may find it very difficult to even pick one! My favorite of them all is their cornbread. That corn bread is so damn good. They make the cornbread with jalapeños so it gives it a nice subtle kick of heat! Some of their other sides options like their baked beans may be basic but nonetheless good in taste. \n\nAlso I recently went here when it was my friends birthday. One of the employees engaged us in a friendly conversation upon noticing that we had a cupcake. When they learned that it was someone's birthday they kindly got a birthday card and had the employees of 4 Rivers sign it and wish our friend a happy birthday! The staff overall was friendly.\n\nDon't be intimidated if their is a long line, it goes by quick and they also have separate lines for pick up and to go orders!",
#   'date': '2016-11-10 01:26:57'},
#  {'review_id': 'DA1hipUiNKokB0wCu7CECQ',
#   'user_id': '8zL6xZjHt8V-Rd-KK-Muiw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "You haven't lived until you try their amazing BBQ!! The best!  Not sure I am in love with the sharing of tables.  A bit awkward.  Would love if they added wine to the beer and cider selections.  Service is fast and friendly.  The Bakery items look amazing but we are usually too full to eat any after our lunch or dinner.",
#   'date': '2018-06-09 02:23:30'},
#  {'review_id': 'ABnlbHOKs7R9cV-ieQURCg',
#   'user_id': 'S5ypM4c_fNVlWKTjaLRJdw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 5,
#   'funny': 2,
#   'cool': 3,
#   'text': "This place is great, and if you haven't checked it out I suggest that you do! I mean haven't you seen everyone driving around with their bumper stickers? \n\nIt can get pretty busy here during lunch so beware. Don't come here to eat if you're in a rush or in a time crunch. \n\nThey have a ton of different sodas to choose from which is always nice. They have Virgil's cream soda (one of my favorites) amount others. Now to the food! \n\nI pretty much always get the Cuban sandwich from here because it's huge! Trust me, my friends always look at my tray and ask what I got and why I got so much (lol). It's really good and it's probably one of my top recommendations. \n\nThe sides is where I believe that this place really shines. All the sides I have tried from here have been great. I recommend the corn and Mac and cheese. Also the bacon wrapped jalapeños are a must! They're not really spicy and they're delicious without being overly greasy. \n\nThey have this really amazing bakery on the inside near the back that is most probably my favorite part of coming here (and I'm not a sweets person). They cupcakes are all amazing, the peanut butter cup and birthday cake are my favorites! \n\nThey also make an amazing cupcake drop shake in which they mix a cupcake of your choice with vanilla or chocolate ice-cream. It's amazing and it will change your life. The shake is great, just imagine having little pieces of a delicious cupcake in a shake. I'm craving one as I write this review right now! I personally like the birthday cake cupcake with vanilla ice cream. \n\nOverall, if you haven't visited this place yet I suggest that you do! It's definitely worth the try and they even have a great bakery with tons of cupcakes and cakes.",
#   'date': '2015-09-24 04:20:26'},
#  {'review_id': 's7kCzDxg3xD73D2a9TjN5A',
#   'user_id': 'bfoshzkJEr7m0D-Ofbp9aA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Let\'s be real...I LOVE this place...I can\'t deny it! If I had a wish, I\'d ask the Rivers family to let hover around in their kitchen and just let me stare at all the food and take in the aroma...oh and of course eat an endless supply of that delicious BBQ!!! I have frequented this place many times and my favorite is the Texas Sausage dinner. You know how they say "everything is bigger in Texas" well I\'ve never been to Texas, but the Sausage that is served seems to fit the saying quite well. It comes with three sides AND a biscuit! I purposely eat less throughout the day if I know I\'m attending this Mecca of BBQ goodness! The brisket, pulled pork, chicken, and burnt ends are BANGING as well. Mr. Rivers, if you\'re reading this...I love what you do with BBQ!!! xoxoxoxo',
#   'date': '2017-02-19 12:04:22'},
#  {'review_id': 'QKBYvgbWgANFDdc0HzoJjw',
#   'user_id': '2rJwbn3BzWPn_Hj5Q8-3MQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 2,
#   'text': "I went with some co-workers for lunch on a Tuesday. If you don't get there right at 11 (opening) the be prepared to wait in a long line. We had no line and I ordered the Longhorn sandwich with the fried pickles and jalapeños wrapped in bacon as a side. Since we were so early, I had to wait for both the fried pickles and my sandwich. \n\nI waited maybe 3 minutes for the sandwich, but the pickles came out maybe 7 minutes later. The server who brought me the pickles apologized for the wait and for the fact I didn't get a full serving of fried pickles because they were still cooking. He promised me more when they were ready. I thanked him, not really expecting him to remember. Boy, was I wrong!  Before half of my sandwich was gone I received a 2nd full serving of the fried pickles!\n\nGood food? - check\nGreat service? - check\nNew convenient east orlando location?? - check. \n\nLove this place!!!!",
#   'date': '2014-06-11 21:39:26'},
#  {'review_id': 'BqsvGAaX-P1UoDoQpT3gyg',
#   'user_id': 'F0G7fulMnGItDWGgGmNa7A',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Me and my fiance visited 4 Rivers for the first time. The food was wonderful even though when we received it the food was a little on the cold side. Seating needs to be re-looked at because there is just not enough seats and the arrangement makes seats that would be available not because you would have to sit with strangers. Overall we will try 4 Rivers again just not this location!!!',
#   'date': '2014-09-26 02:16:11'},
#  {'review_id': 'qsKOB7AYvynfvyxQX7_KMw',
#   'user_id': 'sNVpZLDSlCudlXLsnJpg7A',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "After I completed my last review I was contacted by the restaurant. They were genuinely concerned about the food quality I received and gave me an opportunity to come again and give them another chance. Excellent customer service and I can't wait to give them another try.",
#   'date': '2014-11-30 21:36:00'},
#  {'review_id': 'M-RtyeYoe5GtLsLtLpF48Q',
#   'user_id': 'G1d3Zk3CyR6-k5vcs6iXEQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': "Solid four stars. \n\nMy wife ordered the brisket with smokehouse corn, bbq beans and collard greens. The sides were the real stars. And the biscuit! Oh man...delicious. The brisket was decent. Most of it was fairly dry and needed tons of sauce. The burnt crusty parts were tasty but extremely salty.\n\nI had the St. Louis style ribs and they were very good. The dry rub was great with just amount of sauce and very juicy. The cheese grits were great and the cole slaw was simple without too much mayo, which I really found tasty. The mac and cheese was just ok, nothing special. \n\nOverall, not the best bbq I've had, but very good over most of the menu.",
#   'date': '2015-06-09 01:18:12'},
#  {'review_id': 'v7cNxQZjKWHSzR_F5D_5Zw',
#   'user_id': 'VA1vV3EaD1ohS7gGOLc5WA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': '"Well, that was different..."\n\nOn our first visit, back in Janauary, my wife and I dropped our daughter off for art and bass lessons; and, then we headed over to 4Rivers Smokehouse. We had never dined in, so we were confused as to where the entrance was, as people were walking in through the side awning; and, through the front. \n\nWe settled on the front; and, found the bakery counter. Not wanting to start with dessert, we made our way passed the long, community tables, to the queue. You have to look at the menu, decide what you want, and then "build" your meal by selecting your meat, sides, etc. It\'s kind of like the Chipotle of BBQ.\n\nThere are no plates, the meat is plopped unceremoniously right on the paper, lining your tray, however, the sides are served in small Styrofoam containers. I am not sure if this is economy or ecology driven; but, that\'s how it works. Bottled drinks, OOPS, are in the refrigerated section as you walk up, so grab a drink BEFORE you get to where you order!\n\nI ordered the burnt ends dinner; but, the meat was way past over cooked, a bit mushy and not nearly as smoky as I hoped. I am glad I asked to substitute some of the burnt ends for brisket, as the brisket is much, much better. \n\nMy wife ordered the Beef Rib (what they call the Brontosaurus); and, it was spectacular. I\'ve never seen a rib with so much meat, which tasted so good; and, was so tender. At nearly double the price of everything on the menu, it\'s a treat for sure.\n\nAfter assembling our meal, the bill came, with room for a tip. I foolishly added 10%. I didn\'t know I would have to get my own silverware, find my own place to sit, wrap up my leftovers to-go; and, bus my own table... no tip going forward; sorry folks!',
#   'date': '2016-06-12 16:21:49'},
#  {'review_id': 'zG3_RxU4NjjyY72MCkNAxw',
#   'user_id': '1zW5XQF76NJCh35X_yb9cg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 7,
#   'funny': 1,
#   'cool': 2,
#   'text': "Okay 4 Rivers. Everybodys been there done that... again and again. I am comfortable enough to say I am a fan of this place! It is a great lunch place and good for quick dinners. \n\nI'm a brisket girl. The fattiest piece off that cap fat is mine. It fat make its oh so juicy and tender at the same time protecting all the meat from the heat. It is extremely tender but I'm warning you the seasoning on the outside layer could sky rocket your blood pressure through the roof because of the sodium level. However, I still dig it. The rest of the meat variety are okay. My next fave would probably be the prime rib but sandwich style. The dinner style has it sliced pretty thin and I think that is such a waste of a good lookin steak. I only like sliced pork very thin. (I know i'm picky!!)\n\nOn to the sides, my current faves are their jalapeno sweet corn bread, roasted corn and cole slaw. In my opinion the corn bread wins miles over their biscuit. It is sweet, moist, light on the top but gets denser toward the bottom and has a kick from the jalapeno. The biscuit recipe could use a little tweaking because its often kind of dry and not warm. The sad thing is that adding butter to it doesn't help much. Bummer. Any ways, back to my other faves. The roasted corn is smokey and delicious and the cole slaw is refreshing against all the warm offerings. \n\nI think the best idea is to get a dinner plate (~10-17 dollars) and split it into 2 meals. I promise there will be plenty if you can control yourself and not eat the whole thing in one sitting. \n\nThe Sweet Shop is here too but I can't comment on that cause I honestly don't remember how I felt about it since I haven't ordered in awhile. \n\nLunch around this area is getting pretty popping. Thanks 4Rivers you are in my repertoire of restaurants for lunch!  \n\nTIP: They have a rewards card that allows patrons to get a free meal (?? or something like that) on every 10 visits. Just do a quick sign up on their website!",
#   'date': '2015-03-19 17:04:49'},
#  {'review_id': 'kDFxEe49J6d7CDu1Zmt9XA',
#   'user_id': '3m92zpkeMBSm9ACDYY3oUg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "It has been 4 years since I've been to 4 Rivers Smokehouse and I'm getting really excited for my upcoming trip to Orlando so I can taste this awesome food again. Everything was awesome!!",
#   'date': '2016-06-23 17:48:18'},
#  {'review_id': 'Javlvz1UpW2XqUuySafBvA',
#   'user_id': 'SFv7ksOCzZcyNQH0uaQQTw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': 'It was a great meal and an awesome experience.  Food was great.  Sides were tasty and very filling.  We will be back.  If you want some good smoked meat with a variety of sandwiches and sides and tasty food this place is great.  It is noisy Donne prepared.  They have long tables so be prepared for sharing a meal with strangers...which just makes it even more unique.  It is great to eat where there is a mission beyond just serving food.  Go and check it out.  You will be glad you did.  Awesome experience.  Oh yeah...save room for the chocolate cake for dessert...oh man...well worth the $5.00!',
#   'date': '2017-07-08 23:55:44'},
#  {'review_id': 'DImY5-ZtvLZyhXv9W129ig',
#   'user_id': 'g86couR6Jp0zkActZmZzTA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "We are always craving Texas BBQ, so we try to stop by 4 Rivers when we can.  I like the open large seating of this location compared to some of the other locations we have been too.  As usual there was the ubiquitous line.  Not sure what it is about good BBQ and the ever present lines.  At least we weren't waiting outside like at some of the locations.\n\nWe often get the Texas Destroyer sandwich.  I like the collard greens as well.",
#   'date': '2015-01-19 02:14:06'},
#  {'review_id': '1q3OXjY8WjrUS_WBW3GNLQ',
#   'user_id': 'UyfB2GCb7hbM3ltBYdzKhA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Food so good you won't want to move for hours! Their barbecue sauce makes everything even 10x more addictive. Pulled pork sandwiches here are my go to.",
#   'date': '2018-05-19 16:28:34'},
#  {'review_id': 'yJGDjY-c3JIdmiW_C4GqXg',
#   'user_id': '5EdKTd3Qw0us4cIEM6_CzA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This is the go-to bbq every time someone comes to visit Orlando. Everything is good, fresh and the portions are really big. We even had a friend from Texas say this is his new favorite place- and Texans love their BBQ.',
#   'date': '2016-08-04 21:32:57'},
#  {'review_id': 'kQ8YWsCxMIpvdxuE248PDw',
#   'user_id': 'ezT03GQqRUvhtsiyGHZDww',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "It took me a while to get to this BBQ joint but the wait was well worth it. The friendly staff, good food and amazing bakery shop next to it make this a must if you're in the Orlando area. I tried the brisket sandwich and the ribs with Mac n cheese and bread pudding. Cannot go wrong with the choices here!",
#   'date': '2014-10-12 23:55:32'},
#  {'review_id': 'NNjs6qhF_UExkEQApqAoRw',
#   'user_id': 'L1wBvU24T9O5-fBP6BKWig',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Moist brisket was amazing! This is a terrific BBQ place to get good food for an affordable price. I really enjoyed the bread pudding side as well. It was good enough to be a really good desert. I'll be going back to 4 Rivers many more times in the future.",
#   'date': '2016-08-04 23:01:14'},
#  {'review_id': 'YGiOwgN6Fid7DkVVqgXdKA',
#   'user_id': 'VjyvsKvdKhRwaV6XbljqDQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Had the three sliders, turkey tender and moist. Brisket was excellent the fat melted like butter. The jalapeño links were excellent. Green beans had great flavor, fries were good. Mustard sauce is my favorite as well as their house sauce. Atmosphere is great love the look. Speedy service and very friendly.',
#   'date': '2018-04-28 18:22:26'},
#  {'review_id': 'NP8E1uoZVP6eCTPjkwed1A',
#   'user_id': 'AD-r7m331OTidQLtSdaKcQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Meh. That's all I have to say. Everyone literally raved about this place. I've tried it twice now, I'm still underwhelmed. The food is okay, however I do have to admit that I'm no BBQ connoisseur, I was expecting to be more impressed that I was. I will likely not be returning.",
#   'date': '2015-09-24 22:16:13'},
#  {'review_id': 'F56AI6xdkUOk-KUdlWAg_g',
#   'user_id': 'XlICp0fT303ptBewRu6y-w',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Great place! Great food and cheap for the quantity you can get. I tried the Smoked Turkey, Pulled Chicken, and Brisket sliders and loved every bite. Casual atmosphere with a fun energy. Somewhat busy even at 8pm on a Monday, but good service and quick good food. I highly recommend!',
#   'date': '2017-06-28 17:21:46'},
#  {'review_id': 'e68OTx7B2jyEDSRVmimPNg',
#   'user_id': 'dlfSCqhe0NpvxwOb3o-7lw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "It makes me genuinely mad that this place has 4/5 stars. IT DESERVES ALL FIVE!\n\nForever in love with the food here, and God, don't even get me started on the bakery. You're missing out on life if you haven't gone here at least once!",
#   'date': '2014-10-29 04:52:01'},
#  {'review_id': 'T2OW00tcXovA96fA81zBrA',
#   'user_id': '3KjKwB_SqHaBwKts1C180Q',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'When you are craving for ribs, this is the spot!!! The first time i came here i thought i died and went to ribs heaven! I love it!!! It is worth it. Some locations have a long line, but this one is huge.',
#   'date': '2018-02-25 01:02:41'},
#  {'review_id': 'iEmOwZhIkvqxSChHXpGyVQ',
#   'user_id': 'xZx9IFy0XWCH2lH0X4xncw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 3,
#   'funny': 2,
#   'cool': 3,
#   'text': "4 Rivers is dangerously good. It's also close to my workplace which makes it even more dangerous.\n\nI remember the days of parking across the street, waiting in a long line in the hot sun to order food from a shack, and then proceeding to eat outside on picnic tables. Fast forward many years, and now 4 Rivers has multiple locations, plenty of parking, and seating options with air conditioning.\n\nThey have a few fancy sandwiches with different toppings, but I gravitate towards the simpler meats. The pulled pork and beef brisket - order them! They are my favorites here. You can request a fattier or leaner piece of brisket and they will happily accommodate. Either way, the meat is incredibly tender and moist. Or if you feel like splurging, go for the burnt ends. So so so good. \n\nIn terms of sides, my top picks are the sweet potato casserole and collard greens. Finally, when my husband and I were on our first month of a paleo diet, the first thing we cheated on at the end of the month was a cupcake from the Sweet Shop. Worth every bite.\n\nDespite the Florida heat or long lines, fans of this place will still keep coming back.",
#   'date': '2016-04-12 11:44:38'},
#  {'review_id': 'lqxiHOuwMCc5x16-mcHhpQ',
#   'user_id': 'Pp46HxyKBeR3cRimBdGMIw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "YUMMM!\nThis place was everything I was looking for! Fast and delicious food for a reasonable price. I ordered the pulled pork sandwich with 2 sides- the Mac and cheese and the sweet potato casserole.\n\nThe pulled pork was so tasty and their house barbecue sauce was the icing on the cake! Very filling and delicious. The sweet potato casserole was so yummy too! A little sweet, so if that's not your cup of tea then you should avoid It. The Mac and cheese was okay-- It didn't compare to the other two items.. still tasty though.\n\nThe service was quick too! Despite the long line, It didn't take too long to get to the front. \n\nThe dining area is family style, so you might have to end up sitting next to strangers.. but it's still worth It. \n\nGreat place!",
#   'date': '2018-03-04 19:49:10'},
#  {'review_id': 'Om2vt023UUuIIHbngIOa5A',
#   'user_id': 'ey9f-F1Sn8oBB-4saE5ErQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 1,
#   'cool': 0,
#   'text': "Touristy Q for people who don't know Q. Over done and overly hyped.  There's not much in Orlando for Q to begin with and this is no contender for the real deal. Sorry, go back to BBQ school.",
#   'date': '2015-08-08 22:28:53'},
#  {'review_id': 'lu_RX6GjkOpLISFCF2I0dA',
#   'user_id': 'SyhblYoA97Oca-PcZtqt0g',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Love love LOVE this place. We ordered 1lbs of smoked brisket, a whole smoked chicken, a side of fried okra, and mac/cheese, to-go. \n\nService: The employees here are so ridiculously friendly and will patiently answer any questions you ask, even though the line moves fast, you never feel rushed. \n\nFood: Brisket was phenomenal, though I think someone went a little salt crazy when seasoning this time around. Was still delicious, incredibly flavorful, juicy, hot, and tender, knife not needed, we easily cut it with a fork. We got very little fat, but it just melts in your mouth like butter. \n\nThe smoked chicken was actually amazing! I was skeptical, but boy was I wrong. A wonderful smoked taste, and even the white meat was incredibly juicy. \n\nSomething I wanted to point out; I don\'t know if this was because we ordered it to-go, but it\'s not really a "whole" chicken [ like when you buy rotisserie ] but two 1/2 chickens. No back, neck, butt, etc. We don\'t really care, but I do know people who that would irk, so thought it worth mentioning. \n\nFried okra great as always, as was the mac&cheese, creamy and delicious. \n\nDefinitely recommend this place, we\'ll be back! ~',
#   'date': '2015-01-05 21:32:19'},
#  {'review_id': 'LbXHgtF5i606GzVbR8ujFA',
#   'user_id': 'KLqDESlc7HXegidmQjxH4A',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Definitely the best BBQ I've had in Orlando. Their pulled pork has amazing flavor, the sauces are great, and the baked beans can't be beat!",
#   'date': '2016-12-20 15:37:06'},
#  {'review_id': 'ZFrTTLl32MRQCQ7uaYuFxw',
#   'user_id': 'fCiBh_AmemQDBOZK1lKM7Q',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "This local chain is mandatory to try, unless you're a vegan/vegetarian. I used to drive all the way to the one in Winter Park before this one opened. The main food is exactly the same as the other locations, as it should be: meaty, hearty, and comforting. It used to be so crowded that you'd probably be in line for 30 minutes, but I think that phase has passed. With that being said, parking is not a trouble either. If you're a first timer- get the sample sliders in order to get a taste of a good portion of their menu in one plate offering. Regarding the sweetshop though, particularly their cupcakes, I felt that the cake parts themselves are moist and flavorful. However, thee icing isn't very satisfying. I am not baker but I think perhaps that they put too much of the flavor of the icing in it(chocolate, vanilla, cheerwine), as it is just too overpowering. I find myself throwing the pastry away completely and am utterly disappointed.",
#   'date': '2014-12-19 21:54:30'},
#  {'review_id': 'jvdKClEIaDIXFSlbB0tfQQ',
#   'user_id': '4_c9o4UYfYcC1vfdcsIQpA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'My husband raves about this place all the time - days it\'s the best BBQ he\'s ever tasted.  We stopped at the UCF location in Orlando today as we were packing our girl up to bring her home from college.  "This is the place I always talk about" he says "You\'ll love it".  Sure enough, we were not disappointed.  Among the four of us we had brisket, pulled pork, Texas sausage, and a pulled pork sandwich - the beef brisket was my favorite. We shared sides of mac and cheese, collard greens, green beans, sweet potato casserole, smokehouse corn and corn bread salad. All were delicious; the sweet potato casserole and the corn were my favorite.  We will definitely visit again!',
#   'date': '2015-08-09 00:34:39'},
#  {'review_id': 'KOmR8mhiQdEyB5h5bFS2Zg',
#   'user_id': 'BiZJ5E8DFsh7Z2saolfPig',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Pretty good but you have to make sure you get all your food if you do take out.This has to be the third time we have had take out and they left out part of our order. Check #4189 today was short 2 sides. This is crazy!',
#   'date': '2015-11-19 23:38:12'},
#  {'review_id': 'De3ri1DnNPuHXv4tKM9X6Q',
#   'user_id': 'gXLTS8ftydM1Bsta7VPD-w',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "I have only 3 words: brontosaurus beef rib!\n\nOMG, this food in this place is Ah-may-zing! Now I understand why the line is always out the door and nearly half way around the building.  The food is so delish! It is so difficult to find BBQ beef ribs let alone beef ribs that are juicy and delish!\nI love them for their beef rib, however, my only complaint is that there are VERY few sans-pork options  -- nearly every side has pork in it.  I think the remaining side choices are between Texas cornbread (made with jalapeno), corn and sweet potatoes. The cornbread and corn are very good...I could just eat the cornbread by itself.\n\n***so it is really about a 3.5 star for me - I wish there were more sans-pork side options***\n\n\n××September update xx\nNow that I have a few more visits under my belt, I'd like to add that I've tried many of the sandwiches (pulled chicken, burnt ends, smoked turkey, etc.) and all are pretty good. I like the smokef turkey the best. The beef has gotten to be a tad too salty for me.",
#   'date': '2014-06-29 15:30:46'},
#  {'review_id': 'U5mdgPTnMKdnqHx6c3ZliQ',
#   'user_id': 'Gxzp5e0rPmLotx2xd7rhvw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "Nirvana bbq to me. For someone who doesn't eat a lot of bbq, this place is a real treat for me. It's a little pricey for a college student, but totally worth it in both quality and quantity.  You will definitely have enough to take home sloppy seconds :). I ordered one of their signature stackers, the Messy Pig, with two sides: the crispy creme bread pudding and their sweet potato casserole. You mind as well opt for the sides due to the price of one side alone. More to take home later! Ask them what flavor of bread pudding they have. They switch them out apparently!  I can't wait to come back and try other flavors from them. The crispy creme one was so delectable though. You will not regret it. The sweet potato casserole was rich and delicious as well. And...there are no words for how good and filling the sandwich is...just try it! And douse it with your favorite bbq sauce, whether that be sweet or spicy, you can't go wrong. They also conveniently have to go containers by the drink fountain so you can pack your left overs up for your next meal :)",
#   'date': '2014-04-21 19:21:02'},
#  {'review_id': 'xlhi-PF88SIG78jDsO4yUA',
#   'user_id': 'P4fK3wCygCpxhGUPw7ylgg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Hands down the best barbecue I've ever had. I travel a lot and have never found better in any barbecue across the country. Bonus: the portions are huge for the price, best value + best taste = finest in the land",
#   'date': '2014-10-30 18:39:52'},
#  {'review_id': '8Bh58uFN4le1D02k8Ak9nA',
#   'user_id': '0W-2GTezMmFU-qD8U6PosA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This is one of my favorite steakhouse in town, customer service was fantastic and the food was amazing, specially the brisket',
#   'date': '2018-05-20 04:11:47'},
#  {'review_id': '6NZ1X6ufVUoDiAdh-MTE6A',
#   'user_id': 'bSKjl1di-7QT4Y5p57jOEw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "We have been here many times, this location or in Winter Park the food is always great. Today there was something new, they have always had a friendly efficient staff, but today we had someone get our plastic ware and drinks, almost table service. It was nice. I still like the atmosphere of the Winter Park location better (it's not as loud), but this helped. The food was great as usual, but sometimes it's the little things that make the difference.",
#   'date': '2018-07-27 15:30:52'},
#  {'review_id': 'MSuMqYp9UV-cedmFc7Q3eQ',
#   'user_id': 'cwkB-AWkhCYkjKQkyhK4jQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'It was my first visit to this restaurant and I will be visiting again!! Their brisket is delicious, just fall apart tender. Their Mac and cheese is amazing- and I hate to say this but their bread pudding is so much better than mine it hurts.',
#   'date': '2015-04-17 18:38:41'},
#  {'review_id': 'bDi6esXYoNawP70E1XiT9A',
#   'user_id': 'tG4VdF_J4keDAp07L2ItIA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Now this place holds a happy place in my heart...and stomach because of how simply amazing the food is there. At time of this review, I have tried every Signature Stacker with 2 sides (havent gained a pound so in your face, health science!) and my favorites are the Texas Destroyer and 4R Cuban (oh please who didnt see that coming if you knew me....no im Puerto Rican). Finally, we have a legit BBQ joint here in Orlando so no more Sonny's or Bubbalou's because that's not going to happen in forever. Also try the Sweet Shop with the BEST. FRIGGIN. DESSERT. OPTIONS. EVER. in my humble yet honest opinion of course (MAPLE BACON CUPCAKES, PEOPLE!!!!) Dont mind the wait line, it's only an indicator that its that AWESOME!",
#   'date': '2014-07-14 20:29:03'},
#  {'review_id': 'V4InVNINYDK131VrqU_8OQ',
#   'user_id': '69Px0-y8IbKtgBZZH0bSMA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Oh boy.  Ate here on a recommendation of a work colleague and oh.....my.....lord....\n\nSo much food and so good.  \n\nNext time I will make sure I order less but I had the smokehouse prime rib (just a HUGE pile-o-meat on my tray) the mac and cheese (so good) and fries so I just carbed and proteined myself to death.\n\nDefinately a must visit again place next time I'm in town.",
#   'date': '2016-05-20 21:22:03'},
#  {'review_id': 'qf16T5dxQjY7IsNY7HcLcg',
#   'user_id': 'YoS8j5_ru_I7ut353TwWdA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "4Rivers is a place you can really feel good about eating at. Although my latest visit was a quick in & out to pick up a quick takeout for dinner, I have been a big fan 4Rivers since they opened their first place.  Their bbq is top notch, it doesn't matter if you are a beef, chicken, or pork fan -you will not be disappointed. The brisket is their signature and boy is it delish! They offer well made, make your mouth water, home style sides like macaroni & cheese, collards, okra, and southern green beans.  This is NOT the place to eat if you want your veggies steamed and crunchy.  But if like me you were raised on grandma's home cooking - or you only wish you had a grandma who knew her way around a side of bacon - then you will think you have died and gone to heaven.  Many of the 4R locations also include a Sweet Shop, so if you haven't filled up on brisket and collards, you can top off your meal with a selection of sugary treats.  My personal favorite are the 7 layer bars, just like Grandma used to make, except she called them Hello Dolly Cookies.  Over the years I have also worked multiple times with 4Rivers catering. The folks who take care of the catering business are just as top notch as the people in their restaurants. The quality is just as good when they bring the meal to you and service is top notch and then some. \n\nTo touch base very quickly on 4Rivers the company, I was lucky enough to be a guest at a YMCA breakfast where Johnny Rivers, the founder spoke about how he came to start the company and his corporate philosophy. You can feel good about supporting this company by eating at its restaurants. They are good corporate citizens who support the communities where they make their homes. \n\nSo, what else can I say but 4R!",
#   'date': '2016-08-05 23:40:27'},
#  {'review_id': 'kE5uj4gvk7xYiFsKYVbBGA',
#   'user_id': 'Ko0Q8ORUah0Ja50pG2AgXQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "The line moves quickly and it was worth the wait! I had a pulled pork sandwich with mac n cheese and cole slaw while my daughter had the brisket sandwich with mac n cheese and fries. We also shared a side of Texas cornbread. Every bite was delicious and I would have wanted seconds if we weren't so full. We don't live near this location, but will definitely check out the ones near Tampa.",
#   'date': '2017-04-09 20:25:52'},
#  {'review_id': 'IjSlkz0Vs86UpTnIJz8l9g',
#   'user_id': '0xZucjnNt2beD1veIAWLwA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 2,
#   'text': 'This place is solid! What a great line up of tasty chow served in generous portions. This place does get busy with a line out the door. But the pace was moving pretty steady with open seating without looking too hard. I had the Texas sausage which was phenomenal along with greens, corn and smoked jalapeños. Everything was great and the deserts looked fantastic, too bad there was no room left after cleaning my tray.',
#   'date': '2014-05-09 01:02:50'},
#  {'review_id': '6VE14eJGfQKvRx34NV_PqA',
#   'user_id': 'gIInmgcdNchs9OtFuQd4mA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Wow so slow and rude workers!!! Not only did we wait FOREVER to get our food, the workers were unbelievably unfriendly. Saw no management intervention either. Just let the train wreck get worse and worse. Avoid at all possible cost.',
#   'date': '2015-10-24 19:40:29'},
#  {'review_id': 'AC_g3GJA71Qk5knXxI17Ag',
#   'user_id': 'xrboR3aar6AoNllo03HAhw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Top notch BBQ place. Very casual, but friendly.  Order at the counter and take your food to a table.  Several good meat options (pulled pork, brisket, ribs, etc.), and probably 20 sides. We have yet to find a poor dish.',
#   'date': '2016-10-15 12:56:38'},
#  {'review_id': 'y_JOnYZ5qdr-MpKhUyHROA',
#   'user_id': 'vC8VEwKiCTD2N3w9ei6BsQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I LOVE this place!!! The food is amazing and they have CHEERWINE (soda).\n\nThere are tons of BBQ places around but I have to say that 4RIVERS is by far my favorite.  I tend to be a creature of habit so I always go for the burnt ends sandwich with their baked beans and french fries. Mmmmm Mmmmm! I've tried the moist beef brisket and the beef ribs too. Nothing I've tried has disappointed.\n\nMake sure you try their sweet shop too! The desserts (mainly the oreo cupcake) are to die for!",
#   'date': '2015-02-25 14:10:54'},
#  {'review_id': 'WSFGVvAPs2OpbFgvIVtg4w',
#   'user_id': 'wZyhAv19F_chqnBJgjiDdQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'AMAZING. This is a must eat at place when we are in Orlando. Love everything about this BBQ joint!!',
#   'date': '2017-01-04 01:07:57'},
#  {'review_id': 'dpJ0XrsyJlpcGzd5PAlVsA',
#   'user_id': 'epapdenetZh5EUvPlE7hXA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Normally I love 4 Rivers.  Today we went in to try their brisket burger, their weekly special.  We got there and they were busy, so the wait we had was not unexpected.  What was unexpected was that the burger patties were burnt to a crisp.  Well done all the way through , dry as heck, and burned around the edges.  We did not send them back because we did not want to wait another long time to get our food.  Really disappointed.',
#   'date': '2017-03-16 18:44:01'},
#  {'review_id': 'ZydVUMqgG8DXZb92Y-ITMQ',
#   'user_id': '_IPMua9rBHzZof1AOAqUuQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 1,
#   'cool': 3,
#   'text': 'It\'s hard to say something negative about this place. My dinner was delicious. My plan was to have dessert afterwards because don\'t get me started on how good they looked while I ate my "Sliced Pork" dinner that included a homemade biscuit. I left the biscuit for last because I wanted to attack the mac and cheese and the BBQ baked beans that left me with a WOW face! Once I finished all that I had a piece of the biscuit to see how it taste and even though I was full I kept putting honey and ended up finishing it haha. The biscuit is flaky and I haven\'t had one like this and no other place so a high five for that because I\'m a southern man!  \n4 Rivers has a variety so you will not be disappointed, service is great too!!',
#   'date': '2017-07-30 23:56:01'},
#  {'review_id': 'LhlwN5ialbph7BFYjyGu-A',
#   'user_id': '8lwg9pevZfgP7aTC95p7Ew',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Ok so I've been here a few times and figured it's about time I write a review. So I'd just like to say that I always try the same thing angus brisket. And it always delivers well don't get me wrong I love it. I just wish it would be juicier or a little more flavorful. But to the credit of the establishment they have the option for a moist or lean cut and I suppose that if you don't choose they default you lean meat. I'm sure the moist option is probably what I'm looking for is all. Now that that's out of the way! Do not be mislead the food is great! The Mac and cheese is super cheesy and yummy and the bread is definitely soft and delicious. They ambience is neat very college area vibe which you should expect being next to ucf. They have an array of sodas and juices for you to choose from! 2 other things to note is that they have a barrel in the front that you can wash your hands at which I thought was really neat and a separate section for sweets which looks super tasty but I have to try! Overall good place to grab a bite! O and their bbq sauce is more tangy and sweet than regular sauces so heads up!",
#   'date': '2015-05-28 21:51:30'},
#  {'review_id': '2wytfb_v7Y3MuYOBtlgsIg',
#   'user_id': 'j4lEYEWmfhCIgdcAT7txaQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I've been to many BBQ restaurants across the country and 4Rivers smokehouse is by far the best. The atmosphere, menu, and food is first class. The staff was very friendly and made sure you are satisfied. When I come back to Florida, I'm definitely making my first stop here!!",
#   'date': '2016-03-09 17:10:28'},
#  {'review_id': 'zANYwE8NlugpGqahN8ALSw',
#   'user_id': 'E2CuwvUZdhvrAvvNdmmN8A',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 2,
#   'text': 'Another great 4 Rivers location.\n\nI have already talked about the food and such in other reviews.  This time I would just comment on how gracious the staff can be.   We came in about 8:30pm, not realizing the restaurant closed at 8pm.  The staff graciously served us anything they had left and apologized for being out of a few things!  No one ever rushed us or made us feel bad about being in so late -- even though we did feel bad.\n\nThanks for serving us with such flair even after your closing hour!',
#   'date': '2015-08-22 02:35:27'},
#  {'review_id': 'QLO_y_Mnu4xHQBocuPvoMg',
#   'user_id': '6ljdlfnpJuNF70t63io2fA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I have been a long time resident of Orlando since before this specific location on University was here. This is definitely not my first time at Four Rivers. The barbecue and general ambience are two of the most exceptional things about this place. The place is always spotless even at its most busy times. It is a great place to get stuffed with barbecue and amazing sides with a large group of friends. One of the biggest issues that has developed over the years with Four Rivers is that their attempts at franchising has come at the cost of its uniqueness. The food is very consistent now where as before some days they would experiment and use slightly different recipes. This led to the occasional disappointment such as too salty or soggy brisket but it would also lead to some amazing concoctions. Besides this small issue Four Rivers is a must eat for anyone visiting East Orlando.',
#   'date': '2016-03-10 03:23:35'},
#  {'review_id': '4vCpHOrgS8H-t3vBgDt5rg',
#   'user_id': 'HPnDAIc4Fi3VRVkFa1dc2Q',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "This place is delicious! I'm not a huge BBQ fan, but I enjoyed the food here very much. I had pulled pork and ribs. The meat is so good you don't even have to add BBQ sauce to it! The sweet potato casserole is YUM! I will be going back.",
#   'date': '2014-07-15 04:35:20'},
#  {'review_id': 'sZqrTWHcQs6LgXjYbqd0Sw',
#   'user_id': 'I4cfBoRWEhB90HBdjh8z5Q',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 1,
# ...
#  {'review_id': 'FfWUe6SHA8XAUbRbv6sohA',
#   'user_id': '04QDLvbl2ZDDjJznswVtcA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 1,
#   'text': "4Rivers is always good. Go to any location and you will not be let down if you like a good Texas inspired BBQ meal. Some of my family claims that certain locations are better than others but I find the differences to be very small. The best thing about this location is that the line is usually shorter than the one in Winter Park. \n\nIf you're hanger is in full force, you will want the dinner plate that comes with choice of meat, 3 sides, and bread. I would recommend the brisket. They have salads but no one really orders them. This is mostly a carnivores club. \n\n4Rives has a desert shop that many people also enjoy but the baked goods are not high on my list. They even do wedding cakes if you love them that much. But I come for the meat!",
#   'date': '2016-02-12 19:08:57'},
#  {'review_id': '_GcX1SPJfA-1vgE2B3y9zQ',
#   'user_id': 'ZlzZcW6DVm5pnQYhDh3O0g',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "This place has great food all around and it's very comforting! They have so many delicious sides to chose from!",
#   'date': '2020-10-09 16:05:17'},
#  {'review_id': 'uu41bwmSAm1zc1EHu5xtyQ',
#   'user_id': 'G-ZL5PMIZo_xi22KVwzGvA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "This is the best central Florida has to offer...\nGet the ribs,\nGet a sandwich,\nOrder catering or lunch\nIf your disappointed, it's not the food... your just wrong.   This is the best of central Florida in the southern tradition\nSleeper pick... jalapeños and collard greens",
#   'date': '2020-10-23 00:16:13'},
#  {'review_id': 'XMVF6xuKHIqjB0h3RgMUlA',
#   'user_id': 'E2A25PeZp14pLm5Z1q5Csw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Excellent food! I highly recommend the pulled pork with their signature sauce! But their absolute best food is their sides!\n-BBQ Beans are the perfect consistency and taste (I love baked beans and theirs are the best I have ever had) I usually get two helpings of just the beans because they are so amazing\n-Crispy Bread Pudding is only avail on certain days so I make sure I only eat on those days. This pudding is sooooo good!! You must try it!\n-Mac n Cheese is a tasty option, however not my number 1 choice\n-Sweet potatoes are pretty good as well, but also not a number 1 pick for me\n-Jalapeños are the spiciest peppers I have ever had, so you better be prepared with milk\n-Fries are really good with the signature BBQ sauce \n\nTheir curbside service has been excellent during the pandemic! Keep up the amazing work y'all!",
#   'date': '2020-11-25 01:05:19'},
#  {'review_id': 'KCbghJXTDw0vqS6pAJGl6Q',
#   'user_id': 'Aro3MaxAbDqhR1_hRejcUg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I just went here for the first time.  My husband took me out for a birthday dinner.  Everything was delicious!  Brisket was soooooo tender.  The sides were incredible.  We thoroughly enjoyed our meal.',
#   'date': '2020-11-20 00:25:25'},
#  {'review_id': 'rXCPUrW3hhcy0RSjjCpTWg',
#   'user_id': '8ZtSOkdMg8AwB2PhvXK6ZA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This place is amazing! Cheese grits are a must try. They are solid and you can ask for your meet on cheese grits instead of a bun if you are getting a sandwich. Turkey is great and so it the pulled chicken and pulled pork. Love their meaty baled beans, creamy Mac and cheese and sweet potato casserole. Love how they are closed on Sundays. Everyone needs time off from work.',
#   'date': '2019-06-18 18:04:00'},
#  {'review_id': 'iKPpIUIc4ODiMVbWfm05yg',
#   'user_id': '4RE3jnXQZycbgE4evIlKSA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I can't tell you how disappointing the food was . I realize covid and the whole pandemic has left our world in a different place but I can only say I would never order food from here again . My daughter's graduation  was last Saturday at UCF . All virtual due to the pandemic . Had just my immediate family at house . Spend $ 200 plus for the food to go and I was extremely surprised how bad no other word but bad ) it was . The beef brisket was dry and they gave us tons of fat side not meat . Chicken was down right terrible . Pork was ok and even the corn bread that is always moist and delicious- nope ! I felt bad cause all my family and friends love this place . I will never order from it again . Sonnys bbq -bubbalou's  or Bonfires has way better meats . It's is hard enough to try and celebrate such life's accomplishments and food is always the best part ... not here at 4 Rivers .",
#   'date': '2020-12-24 12:55:51'},
#  {'review_id': 'ojOyKTQPizkG3mKbcrXzUA',
#   'user_id': 'Wg7-CVh1iyEGfo6blcJ7Pg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 3,
#   'funny': 0,
#   'cool': 3,
#   'text': "This place is so good. The flavor of their food is unlike any other BBQ place around. I had the blackened tips with mac & cheese, sweet potato casserole & bacon wrapped stuffed jalapenos. The jalapeno cornbread is the finishing touch. Everything was delicious. Nice smokey flavor and cooked to perfection. We stopped at the bakery on the way out and got some gigantic cookies to take home. They even had a gluten free selection. I would recommend this place to anyone looking for a great tasting, casual dining bbq spot. I'll definitely be returning.",
#   'date': '2019-11-10 00:10:51'},
#  {'review_id': 'NYL-sNoWVZbYNRjWmoUPUg',
#   'user_id': '81xPLX8YJjzqSwwrSqCdEg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I've been to most of the 4 Rivers in metro Orlando and this one is the worst. The portions were small, the meat was greasy, fatty, and the bread was stale. Extremely disappointed as I was ordering for a first timer & I love 4R. Not this one. I'm never eating here again.",
#   'date': '2020-10-16 13:36:37'},
#  {'review_id': 'fxRbfe1NGm_7TEHGnAb5tw',
#   'user_id': 'EZihv_Rrb773WXCK-6R7iA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I attempted to order the Tri-Tip with corn for a side and because of Covid . They did not serve  it . The Bake Shop is no longer open because of the covid ... everything is because of the Covid...I use to come into the restaurant and it was packed ....today it was empty...sad to see it has gone down ...I will tell you the young gentleman that helped me in the To go area tonight was very helpful . The only problem was not having the menu items I wanted...The restaurant really needs to get the Tri-Tip and the corn back on the menu . It also needs to open the bake shop . Things need to get back to normal!!!',
#   'date': '2020-08-31 22:10:17'},
#  {'review_id': '6Dlm-L2oEcwrPeq2uL6hTw',
#   'user_id': 'AcQZdEApTK0KcDfrrWnjZA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'The pulled pork bbq is amazing but the sides are out of this world delish. The Mac and cheese and sweet potatoes are the best thing ever. And the deserts are so good you want to try one of each!',
#   'date': '2018-07-03 04:36:20'},
#  {'review_id': '-eOEvDBjbgpSXX_et6W9Lw',
#   'user_id': 'nr4dNrsVr-RIBdeGMg64Rg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 2,
#   'funny': 2,
#   'cool': 2,
#   'text': "Five stars for high quality barbecue. I've never been disappointed with the food at 4 Rivers. I usually get the pulled pork sandwich with 2 sides - Mac & cheese and banana bread pudding. Do not miss out on the bread pudding, it's SO good. Recently I've discovered what I think is the best item on their menu: the BBQ Quesadilla. I got it with pulled pork and it's amazing! Overall, 4 Rivers has some delicious food, a great well-branded atmosphere, and quality across the board. Make sure to stop by their dessert section and grab a cookie on the way out!",
#   'date': '2017-12-02 01:01:14'},
#  {'review_id': '9wx3q1idW3eeqaot0PwqeQ',
#   'user_id': 't-MbBRkNIR0eM_Ha2dAF0w',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 4,
#   'funny': 1,
#   'cool': 3,
#   'text': "4 Rivers is pretty much known throughout central Florida.  Their brisket is top notch.  On this particular visit, I was excited to try their new Burnt Ends made from Beyond Meat (aka not real meat).\n\nOf all of the faux meats I have tried (Impossible Whopper at BK, Impossible Slider at White Castle, Beyond Taco at Del Taco), this is by far the best I've had.  I was surprised at how delicious this plant-based BBQ was.  Each bite was smokey, chewy, and tasted like any good barbecue I have had.  I give this product 5 stars for flavor.\n\nThe Thai Salad was a little lacking in flavor for me.  All of the veggies were fresh, I was just expecting more punch or something.  Maybe the Beyond Burnt Ends were so good that it made this salad pale in comparison, who knows.  It wasn't bad, but I'm not ordering that again.\n\nMy wife enjoyed the Six Shooter sandwich.  The bananas foster bread pudding was also quite delicious.\n\nKeep up the innovations!  If Beyond Brisket ever comes out, I'll be there for it!",
#   'date': '2019-11-25 15:52:42'},
#  {'review_id': 'KH1V4muy5765v6xlqgurEQ',
#   'user_id': 'UXX3Mk4ocxNt3N4LxOnz8A',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 4.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': "If you want some tasty BBQ while in the Orlando area this is your place! I ordered two meats and two sides. I asked for pulled pork and brisket as well as a side of mashed sweet potato and Cole slaw. Everything was delicious. You can ask for your brisket moist or lean. I opted for moist. You can't go wrong. Pulled pork was fantastic and their bbq sauce was scrumptious. My hubby got their St. Louis ribs and Mac and cheese. Wow! Get the ribs! I wish I had. Mac and Cheese was rich, creamy and full of flavor. They also have a bakery attached to the facility. We got a massive chocolate chip cookie. As soon as she split the cookie in half chocolate was oozing out. Ugh, so so good!",
#   'date': '2020-03-13 12:18:25'},
#  {'review_id': 'qxaSVvf4rRgNvclTulyg7g',
#   'user_id': 'a4m4ZwQu_0zsJhTrAHBsdA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': "So we came here with some friends for dinner one night. I love this place.\n\nI ordered the Burnt-Ends (4R signature brisket shredded with pulled pork, smothered with signature sauce and re-smoked to perfection) Dinner with three sides (smoked jalapenos, french fries, and fried okra) and a biscuit. My girlfriend for the Pulled Pork Dinner with three sides (4R BBQ Beans, Mac & Cheese, and the Bread Pudding) and Texas Cornbread.\n\nSo a couple tips. First of all, you can substitute Texas Cornbread for the biscuit when you order a dinner, and I recommend you do it. Their cornbread is to die for. Also, in case you didn't know this, the Bread Pudding here is made with Krispy Kreme donuts. I don't think I have to say anything more here. It's delicious. It's not too sweet, contrary to what you're probably imagining right now. \n\nThe burnt ends is my favorite meat here. It's so smoky and tender and juicy, you don't even need the sauce on there for it to be delicious. The smoked jalapenos are always amazing. They're smoked with a piece of cheese in them and wrapped in bacon. My only complaint is that I only get two as a side. French fries were crinkle cut, standard. The fried okra is always hit or miss, honestly. This time, it was a hit. I loved them. Super crunchy with the okra still ok and delicious inside the breading. \n\nMy girlfriend's pulled pork was also delicious. I like pulled pork that's not like, too fatty. Just meat. So good. Her beans were beans, and the mac & cheese was mac & cheese. Standard stuff, but the standard is appreciated compared to when other restaurants get it wrong. \n\nSo if you haven't come here yet, and you're reading this, please come here. Please. Please.",
#   'date': '2017-01-23 00:50:01'},
#  {'review_id': 'f6EATMkzhSZPy9OZWeEr9g',
#   'user_id': 'cy4IhuRc5Bjj-vEwLrvzmQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Thank you for including such delicious vegan options in your menu (for me) and awesome bbq (for my husband). We love having this for take out during covid-19.',
#   'date': '2020-07-03 14:43:12'},
#  {'review_id': 'O2KDMQlWuOKO7emPyEJlsQ',
#   'user_id': '7PZHU3pUGlyEybqOtuqvxQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "Service is fast, food is good but it's far from Texas eaten. I would recommend a larger selection of barbecue sauces, smoking the meat with Mesquite and keeping it warm. I would also recommend keeping the utensil dispenser full eating food with a spoon is a little more difficult I prefer fork but all said the meal was good the macaroni and cheese was delicious along with the collar greens.",
#   'date': '2019-07-27 11:26:45'},
#  {'review_id': 'pcimWnNqIiBQtbAENe4ipg',
#   'user_id': 'yiAL6zbPAPMM-AYbec1z5w',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "You can never go wrong with 4 Rivers, by far the best bbq food I've ever had. We switched our orders up, I got grilled chicken with green beans and corn. I can't decide which side I love more. My boyfriend got the longhorn sandwich which was huge and overall delicious!",
#   'date': '2018-04-18 18:54:36'},
#  {'review_id': 'ObrbpeuTpWA-YeAIVpQ8Zg',
#   'user_id': '7Or6leKi8MOQZPyKFveTfg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'This place is outstanding.  We were introduced to it by our daughter and her husband over nine years ago.  It has never disappointed.',
#   'date': '2020-07-07 16:48:30'},
#  {'review_id': '9DflUraTPC59asVgABQ6kA',
#   'user_id': 'pkIlOCn5YAdnT5rQf9fGkQ',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "The food was cold when we got it and it wasn't just one of us it was all of our food it was cold they overall decent employees and help when we did have ask about it and it was good so I couldn't be that mad",
#   'date': '2020-02-27 23:57:21'},
#  {'review_id': 'mHy-STm519haQFqM3hNv2w',
#   'user_id': 'pD71sZ6apLl6LJ5h8UEJTA',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "My coworkers got the before me and enjoyed their meals. I got a salad and the cucumbers, garbanzo beans and half of the lettuce was frozen. The server opened the box and couldn't have missed it but served it anyways. Due to my late arrival, I didn't go back up the counter but I won't get a salad from them again.",
#   'date': '2019-11-05 13:23:14'},
#  {'review_id': '06adVCq4C4aYLS_bBPHsew',
#   'user_id': 'wsOShCceVRTx3WbRuZ1bkg',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 1,
#   'text': "So yummy. The people are friendly and it's clean. Definitely try the Mac and cheese. That's my favorite",
#   'date': '2020-11-22 13:37:09'},
#  {'review_id': 'u5YAOU8LL3cUv_MpEjyg0g',
#   'user_id': 'fYsKMiw3m-uObx7bizrZOw',
#   'business_id': 'xRnhBtG63UNqQaC7wJUUZA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "It's ok , I expected way more from the brisket, meat was seasoned , food was ok , the service was great , didn't wat in due to over crowded",
#   'date': '2020-03-02 13:32:45'}]

# %%
# get all of the reviews in the corpus
# then run tf idf on it,
